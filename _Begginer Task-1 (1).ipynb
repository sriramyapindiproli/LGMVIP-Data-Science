# %% [markdown]
# # LGM VIP Internship - LetsGrowMore
# ## Data Science Internship task 1
# ### IrisFlower classification ML Project

# %% [markdown]
# # Steps to build a ML model:

# %% [markdown]
# ### 1.import dataset
# ### 2.visualizing the dataset
# ### 3.Data Preparation
# ### 4.Training the algorithm
# ### 5.Making Prediction
# ### 6.Model Evolution

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1.Importing Dataset

# %%
df=pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data=df.groupby("Species")

# %%
data.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#              Species
# 0        Iris-setosa
# 1        Iris-setosa
# 2        Iris-setosa
# 3        Iris-setosa
# 4        Iris-setosa
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# 100   Iris-virginica
# 101   Iris-virginica
# 102   Iris-virginica
# 103   Iris-virginica
# 104   Iris-virginica

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## 2.Visualizing the dataset

# %%
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b2f082850>,
#   <matplotlib.lines.Line2D at 0x19b2f082bb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19b2f082f10>,
#   <matplotlib.lines.Line2D at 0x19b2f09a2b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19b2f0824f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b2f09a610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b2f09a970>],
#  'means': []}

# %%
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b2f16c5e0>,
#   <matplotlib.lines.Line2D at 0x19b2f16c940>],
#  'caps': [<matplotlib.lines.Line2D at 0x19b2f16cca0>,
#   <matplotlib.lines.Line2D at 0x19b2f176040>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19b2f16c250>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b2f1763a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b2f176700>],
#  'means': []}

# %%
plt.boxplot(df['PetalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b2f1d1280>,
#   <matplotlib.lines.Line2D at 0x19b2f1d15e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19b2f1d1880>,
#   <matplotlib.lines.Line2D at 0x19b2f1d1b20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19b2f1c0f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b2f1d1e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b2f1dd220>],
#  'means': []}

# %%
plt.boxplot(df['PetalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b2f233250>,
#   <matplotlib.lines.Line2D at 0x19b2f2335b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19b2f233910>,
#   <matplotlib.lines.Line2D at 0x19b2f233c70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19b2f224e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b2f233fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b2f23f370>],
#  'means': []}

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df=pd.read_csv("iris.csv")
for i in df.columns:
    plt.scatter(df[str(i)],df['SepalLengthCm'])
    plt.xlabel(i)
    plt.ylabel("Speal Length Cm")
    plt.show()

# %%
sns.pairplot(df,hue='Species')

# %%
col=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
plt.figure(figsize=(35,5))
i=1
for e in col:
    plt.subplot(1,10,i)
    sns.distplot(df[e])
    i=i+1
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"SepalLengthCm").add_legend()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"SepalWidthCm").add_legend()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalLengthCm").add_legend()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalWidthCm").add_legend()
# Out:
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MY PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig,axes=plt.subplots(2,2,figsize=(16,12))
axes[0,0].set_title("Distribution of Sepal Length")
sns.violinplot(y="SepalLengthCm",x="Species",data=df,orient='v',ax=axes[0,0])
axes[0,1].set_title("Distribution of Sepal Width")
sns.violinplot(y="SepalWidthCm",x="Species",data=df,orient='v',ax=axes[0,1])
axes[1,0].set_title("Distribution of Petal Length")
sns.violinplot(y="PetalLengthCm",x="Species",data=df,orient='v',ax=axes[1,0])
axes[1,1].set_title("Distribution of Petal Width")
sns.violinplot(y="PetalWidthCm",x="Species",data=df,orient='v',ax=axes[1,1])
# Out:
# <AxesSubplot:title={'center':'Distribution of Petal Width'}, xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# ## 3.Data Preparation

# %%
df.drop('Id',axis=1,inplace=True)

# %%
sp={'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3}

# %%
df.Species=[sp[i] for i in df.Species]

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        1
# 1              4.9           3.0            1.4           0.2        1
# 2              4.7           3.2            1.3           0.2        1
# 3              4.6           3.1            1.5           0.2        1
# 4              5.0           3.6            1.4           0.2        1
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        3
# 146            6.3           2.5            5.0           1.9        3
# 147            6.5           3.0            5.2           2.0        3
# 148            6.2           3.4            5.4           2.3        3
# 149            5.9           3.0            5.1           1.8        3
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
Y=df.iloc[:,4]

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.32,random_state=42)

# %% [markdown]
# ## 4.Training Model

# %%
model=LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-34bb74c3eda0> in <module>
# ----> 1 model=LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y) #coef of prediction
# Out:
# 0.9304223675331595

# %%
model.coef_
# Out:
# array([-0.10974146, -0.04424045,  0.22700138,  0.60989412])

# %%
model.intercept_
# Out:
# 1.192083994828144

# %% [markdown]
# ## 5.Making Predictions:

# %%
Y_pred=model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37267f79cd4b> in <module>
# ----> 1 Y_pred=model.predict(X_test)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## 6.Model Evolution

# %%
print("Mean Squared Error: %.2f" %np.mean((Y_pred-Y_test)**2))
# Out:
# Mean Squared Error: 0.04
